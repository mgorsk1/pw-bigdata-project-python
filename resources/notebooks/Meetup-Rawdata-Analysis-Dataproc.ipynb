# %% [markdown]
# ### Load Data

# %% [markdown]
# #### Connect to Spark & Elasticsearch, gather raw data

# %%
import sys
# !{sys.executable} -m pip install findspark plotly colorlover scipy numpy

# %%
#import findspark
import os

from pyspark import SparkContext
from pyspark.sql import SparkSession, SQLContext

# os.environ['PYSPARK_SUBMIT_ARGS'] = '--jars jars/elasticsearch-spark-20_2.11-6.5.1.jar pyspark-shell'

#findspark.init()

sc = SparkContext(appName="esAnalytics")
sqlContext = SQLContext(sc)

# spark = SparkSession.builder \
#     .master("local[*]") \
#     .appName("meetup") \
#     .config("spark.some.config.option", "some-value") \
#     .config("spark.sql.crossJoin.enabled", "true") \
#     .getOrCreate()

spark = SparkSession.builder \
    .master("yarn") \
    .appName("meetup") \
    .config("spark.some.config.option", "some-value") \
    .config("spark.sql.crossJoin.enabled", "true") \
    .getOrCreate()

# %%
spark

# %%
# from json import loads, dumps

# es_read_conf = {
# "es.nodes" : 'elastic',
# "es.port" : '9200',
# "es.resource" : 'meetup-rawdata-*/default'
# }

# raw_data = sc.newAPIHadoopRDD(
# inputFormatClass="org.elasticsearch.hadoop.mr.EsInputFormat",
# keyClass="org.apache.hadoop.io.NullWritable",
# valueClass="org.elasticsearch.hadoop.mr.LinkedMapWritable",
# conf=es_read_conf)

# raw_data = raw_data.map(lambda v: loads(dumps(v[1])))

# df = sqlContext.createDataFrame(raw_data)

# %%
#df = spark.read.json("./data/meetup-rawdata/*json")
df = spark.read.json("gs://pw-bd-project-meetup-rawdata/*json")
# add - select only columns used later on
df.cache()
df.count()

# %% [markdown]
# #### Select only last response for each rsvp_id

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import row_number, col

rsvpWindowSpec = Window.partitionBy(df["rsvp_id"]).orderBy(df["mtime"].desc())

df = df \
    .withColumn("rowId", row_number().over(rsvpWindowSpec)) \
    .where("rowId = 1") \
    .sort("rsvp_id")

# %% [markdown]
# #### Establish timezone, day_of_week_local, hour_local, minute_local of event.event_time based on venue.venue_geo

# %%
# import pytz

# from datetime import datetime
# from tzwhere import tzwhere

# from pyspark.sql.functions import udf
# from pyspark.sql.types import StringType, ArrayType

# @udf(StringType())
# def udf_timezone_by_geo(lat, lon):
#     t = tzwhere.tzwhere()
    
#     return t.tzNameAt(float(lat), float(lon))

# @udf(ArrayType(StringType()))
# def udf_localize_with_timezone(utc_time, timezone_str):
    
#     epoch_utc = int(utc_time)
    
#     timezone_str = timezone_str.strip()
    
#     # check if provided in ms or s:
#     if len(str(epoch_utc)) == 13:
#         epoch_utc = epoch_utc / 1000

#     # get time in UTC
#     utc_dt = datetime.utcfromtimestamp(epoch_utc)

#     # convert it to tz
#     tz = pytz.timezone(timezone_str)
#     dt = utc_dt.astimezone(tz)

#     offset = dt.utcoffset().total_seconds()

#     local_dt = datetime.utcfromtimestamp(epoch_utc + offset)
    
#     parts = dict(year_local=local_dt.year,
#                  month_local=local_dt.month, 
#                  day_local=local_dt.day, 
#                  weekday_local=local_dt.isoweekday(),
#                  hour_local=local_dt.hour, 
#                  minute_local=local_dt.minute)
    
#     return list(parts.values())

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType, ArrayType

from datetime import datetime

@udf(ArrayType(StringType()))
def udf_extract_date_parts(utc_time):
    try:
        epoch_utc = int(utc_time)
        
        epoch_utc_len = len(str(epoch_utc))
        
        # check if provided in ms or s:
        if epoch_utc_len > 10:
            epoch_utc = epoch_utc / (10**(epoch_utc_len-10))

        # get time in UTC
        utc_dt = datetime.utcfromtimestamp(epoch_utc)
    
        parts = dict(year_local=utc_dt.year,
                     month_local=utc_dt.month, 
                     day_local=utc_dt.day, 
                     weekday_local=utc_dt.isoweekday(),
                     hour_local=utc_dt.hour, 
                     minute_local=utc_dt.minute)
        
    except Exception:
        parts = {i:-1 for i in range(6)}
    finally:
        return list(parts.values())

# %%
# # to optimize matching event.time with venue.lat/venue.lon create dict with distinct venues

# from pyspark.sql.functions import concat, lit

# venueGeoDict = df \
#     .select(col("venue.lat"), col("venue.lon")) \
#     .distinct() \
#     .withColumn("key", concat(col("lat"), lit("_"), col("lon"))) \
#     .withColumn("event_timezone", udf_timezone_by_geo(col("lat"), col("lon"))) \
#     .select(col("key"), col("event_timezone"))

# venueGeoDict.show(5)

# %%
# dfWithEventTimezone = df \
#     .join(venueGeoDict, concat(col("venue.lat"), lit("_"), col("venue.lon")) == venueGeoDict.key, 'cross') 

dfWithEventTimeParts = df \
    .where(col("event.time").isNotNull()) \
    .withColumn("event_time_parts", udf_extract_date_parts(df.event.time))

dfWithEventTimeParts = dfWithEventTimeParts.where(dfWithEventTimeParts.event_time_parts[1] > 0)

dfWithEventTimeParts.cache()

# %%
dfWithEventTimeParts \
    .select(col("event.time"), col("event_time_parts")) \
    .show(5)

# %% [markdown]
# ### Analyze

# %% [markdown]
# #### Calculate & visualize most distinguishable distributions of meetings in particular day_of_week_local by tag (Jensen–Shannon divergence)

# %%
# total distribution

from pyspark.sql.functions import lit, count, udf, collect_list
from pyspark.sql.types import StringType, DoubleType, MapType

countByAllWindowSpec = Window.partitionBy(lit(1))

totalWeekdayDistribution = dfWithEventTimeParts \
    .withColumn("event_isoweekday", dfWithEventTimeParts.event_time_parts[3]) \
    .select(col("rsvp_id"), col("event_isoweekday"), count(col("rsvp_id")).over(countByAllWindowSpec).alias("count_all")) \
    .groupBy(col("event_isoweekday"), col("count_all")) \
    .count() \
    .sort("event_isoweekday") \
    .withColumn("weekday_total_dist", col("count")/col("count_all")) \
    .groupBy() \
    .agg(collect_list(col("weekday_total_dist")).alias("weekday_total_dist"))

totalWeekdayDistribution.show()

# %%
totalWeekdayDistribution.collect()

# %%
# distribution by group topic
from pyspark.sql.functions import explode, lower, coalesce, abs, max, rank
from pyspark.sql.types import Row

countByTopicWindowSpec = Window.partitionBy("group_topic")

topicWeekdayDistributionTmp = dfWithEventTimeParts \
    .withColumn("event_isoweekday", dfWithEventTimeParts.event_time_parts[3]) \
    .select(col("rsvp_id"), col("event_isoweekday"), explode(col("group.group_topics")).alias("group_topic_map")) \
    .withColumn("group_topic", col("group_topic_map")) \
    .withColumn("total_topic_count", count("rsvp_id").over(countByTopicWindowSpec)) \
    .drop("group_topic_map") \
    .groupBy(col("event_isoweekday"), col("group_topic"), col("total_topic_count")) \
    .count() \
    .sort(col("group_topic"), col("event_isoweekday"))

# topicWeekdayDistributionTmp.show(30)

topics = topicWeekdayDistributionTmp.select(col("group_topic").alias("group_topic_tmp")).distinct()
weekdays = sc.parallelize(list(range(7))).map(lambda x: Row(event_isoweekday_tmp=str(1 + int(x)))).toDF()
cross = weekdays.crossJoin(topics).withColumn("count_tmp", lit(0))

# ensure that every topic has entry for every weekday (even if no meetings took place on that weekday)
topicWeekdayDistribution = cross \
    .join(topicWeekdayDistributionTmp, (topicWeekdayDistributionTmp.event_isoweekday == cross.event_isoweekday_tmp) & (topicWeekdayDistributionTmp.group_topic == cross.group_topic_tmp), how='outer') \
    .withColumn("event_isoweekday", col("event_isoweekday_tmp")) \
    .withColumn("group_topic", col("group_topic_tmp")) \
    .withColumn("count", coalesce("count", "count_tmp")) \
    .withColumn("total_topic_count", coalesce("total_topic_count", lit(-1))) \
    .drop("event_isoweekday_tmp", "group_topic_tmp", "count_tmp") \
    .sort("group_topic", "event_isoweekday") \
    .withColumn("weekday_topic_dist", abs(col("count")/col("total_topic_count"))) \
    .groupBy("group_topic") \
    .agg(collect_list(col("weekday_topic_dist")).alias("weekday_topic_dist"), max(col("total_topic_count")).alias("topic_count")) \
    .withColumn("topic_count_rank", rank().over(Window.partitionBy(lit(1)).orderBy(col("topic_count"))))

topicWeekdayDistribution.show(20)
topicWeekdayDistribution.cache()

# %%
# JS Divergence UDF

from numpy import asarray, e
from scipy import stats

from pyspark.sql.functions import udf
from pyspark.sql.types import DoubleType

@udf(DoubleType())
def udf_jsd(p, q, base=e):
    '''
        Implementation of pairwise `jsd` based on  
        https://en.wikipedia.org/wiki/Jensen%E2%80%93Shannon_divergence
    '''
    try:
        ## convert to np.array
        p, q = asarray(p), asarray(q)
        ## normalize p, q to probabilities
        p, q = p/p.sum(), q/q.sum()

        m = 1./2*(p + q)

        return float(stats.entropy(p,m, base=base)/2. +  stats.entropy(q, m, base=base)/2.)
    except:
        return -1

# %%
h = topicWeekdayDistribution.groupBy("topic_count").count().orderBy("topic_count").repartition(1)
#h.write.format("com.databricks.spark.csv").csv("gs://pw-bd-project-meetup-rawdata/hist")
#h.show()

# %%
# calculate Jensen-Shannon Divergence per topic & select 10 highest
jsDivergence = topicWeekdayDistribution \
    .crossJoin(totalWeekdayDistribution) \
    .withColumn("jsd", udf_jsd(col("weekday_topic_dist"), col("weekday_total_dist"))) \
    .sort(col("jsd").desc()) \
    .where(topicWeekdayDistribution.topic_count > 1000)

jsDivergence.cache()
jsDivergence.count()

# %%
jsDivergence.sort(col("jsd").desc()).show(100)

# %%
def plot_hist(data_list):
    import plotly.graph_objs as go
    from plotly.offline import init_notebook_mode, iplot
    from math import ceil
    import plotly
    
    init_notebook_mode(connected=True)
    
    from json import loads
    # import colorlover as cl

    no = len(data_list)
    
    colsNo = 5
    rowsNo = ceil(no/colsNo)
    
#     color = cl.scales['11']['div']['RdBu']
    
#     select = [1,2,-1,-2,3]
#     color = [color[i] for i in select]

    color = ['rgb(178,24,43)', 'rgb(214,96,77)', 'rgb(5,48,97)', 'rgb(33,102,172)', 'rgb(244,165,130)']
    
    fig = plotly.tools.make_subplots(rows=rowsNo, 
                              cols=colsNo, 
                              subplot_titles=['<b>{}</b><br>(JSD: {:.2f} Count: {})'.format(loads(x).get('group_topic', ''),
                                                                    loads(x).get('jsd', ''), loads(x).get('topic_count', ''))
                                                                     for x in data_list],
                              
                              shared_yaxes=True
                             )

    fig['layout'].update(height=rowsNo*300, 
                         width=colsNo*300, 
                         title='Most characteristic weekday dist', 
                         showlegend=False)

    i = 0
    
    rows = [x+1 for x in range(rowsNo)]
    cols = [x+1 for x in range(colsNo)]
    
    combos = [(i,j) for i in rows for j in cols]
    
    ci = 0
    
    for data in data_list:
        ci += 1

        c = color[(ci % colsNo)]
        combo = combos[i]
        
        cur_row = combo[0]
        cur_col = combo[1]
        
        data = loads(data)

        x = [x+1 for x in range(7)]
        y1 = data.get('weekday_topic_dist', [0 for x in range(6)])
        y2 = data.get('weekday_total_dist', [0 for x in range(6)])

        title = data.get('group_topic', 'na')

        fig.append_trace(go.Bar(x=x,y=y1,marker=dict(color=[c for i in range(7)])), cur_row, cur_col)
        fig.append_trace(go.Scatter(x=x,y=y2,mode='lines',line=dict(color='gray',width=3,shape='spline')), cur_row, cur_col)
        
        i += 1
        
    plotly.offline.plot(fig, filename='plotly-distribution.html')
    
entries = jsDivergence.toJSON().take(200)

plot_hist(entries)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]      [ (1,2) x2,y1 ]      [ (1,3) x3,y1 ]      [ (1,4) x4,y1 ]      [ (1,5) x5,y1 ]
# [ (2,1) x6,y2 ]      [ (2,2) x7,y2 ]      [ (2,3) x8,y2 ]      [ (2,4) x9,y2 ]      [ (2,5) x10,y2 ]
# [ (3,1) x11,y3 ]     [ (3,2) x12,y3 ]     [ (3,3) x13,y3 ]     [ (3,4) x14,y3 ]     [ (3,5) x15,y3 ]
# [ (4,1) x16,y4 ]     [ (4,2) x17,y4 ]     [ (4,3) x18,y4 ]     [ (4,4) x19,y4 ]     [ (4,5) x20,y4 ]
# [ (5,1) x21,y5 ]     [ (5,2) x22,y5 ]     [ (5,3) x23,y5 ]     [ (5,4) x24,y5 ]     [ (5,5) x25,y5 ]
# [ (6,1) x26,y6 ]     [ (6,2) x27,y6 ]     [ (6,3) x28,y6 ]     [ (6,4) x29,y6 ]     [ (6,5) x30,y6 ]
# [ (7,1) x31,y7 ]     [ (7,2) x32,y7 ]     [ (7,3) x33,y7 ]     [ (7,4) x34,y7 ]     [ (7,5) x35,y7 ]
# [ (8,1) x36,y8 ]     [ (8,2) x37,y8 ]     [ (8,3) x38,y8 ]     [ (8,4) x39,y8 ]     [ (8,5) x40,y8 ]
# [ (9,1) x41,y9 ]     [ (9,2) x42,y9 ]     [ (9,3) x43,y9 ]     [ (9,4) x44,y9 ]     [ (9,5) x45,y9 ]
# [ (10,1) x46,y10 ]   [ (10,2) x47,y10 ]   [ (10,3) x48,y10 ]   [ (10,4) x49,y10 ]   [ (10,5) x50,y10 ]
# [ (11,1) x51,y11 ]   [ (11,2) x52,y11 ]   [ (11,3) x53,y11 ]   [ (11,4) x54,y11 ]   [ (11,5) x55,y11 ]
# [ (12,1) x56,y12 ]   [ (12,2) x57,y12 ]   [ (12,3) x58,y12 ]   [ (12,4) x59,y12 ]   [ (12,5) x60,y12 ]
# [ (13,1) x61,y13 ]   [ (13,2) x62,y13 ]   [ (13,3) x63,y13 ]   [ (13,4) x64,y13 ]   [ (13,5) x65,y13 ]
# [ (14,1) x66,y14 ]   [ (14,2) x67,y14 ]   [ (14,3) x68,y14 ]   [ (14,4) x69,y14 ]   [ (14,5) x70,y14 ]
# [ (15,1) x71,y15 ]   [ (15,2) x72,y15 ]   [ (15,3) x73,y15 ]   [ (15,4) x74,y15 ]   [ (15,5) x75,y15 ]
# [ (16,1) x76,y16 ]   [ (16,2) x77,y16 ]   [ (16,3) x78,y16 ]   [ (16,4) x79,y16 ]   [ (16,5) x80,y16 ]
# [ (17,1) x81,y17 ]   [ (17,2) x82,y17 ]   [ (17,3) x83,y17 ]   [ (17,4) x84,y17 ]   [ (17,5) x85,y17 ]
# [ (18,1) x86,y18 ]   [ (18,2) x87,y18 ]   [ (18,3) x88,y18 ]   [ (18,4) x89,y18 ]   [ (18,5) x90,y18 ]
# [ (19,1) x91,y19 ]   [ (19,2) x92,y19 ]   [ (19,3) x93,y19 ]   [ (19,4) x94,y19 ]   [ (19,5) x95,y19 ]
# [ (20,1) x96,y20 ]   [ (20,2) x97,y20 ]   [ (20,3) x98,y20 ]   [ (20,4) x99,y20 ]   [ (20,5) x100,y20 ]
# [ (21,1) x101,y21 ]  [ (21,2) x102,y21 ]  [ (21,3) x103,y21 ]  [ (21,4) x104,y21 ]  [ (21,5) x105,y21 ]
# [ (22,1) x106,y22 ]  [ (22,2) x107,y22 ]  [ (22,3) x108,y22 ]  [ (22,4) x109,y22 ]  [ (22,5) x110,y22 ]
# [ (23,1) x111,y23 ]  [ (23,2) x112,y23 ]  [ (23,3) x113,y23 ]  [ (23,4) x114,y23 ]  [ (23,5) x115,y23 ]
# [ (24,1) x116,y24 ]  [ (24,2) x117,y24 ]  [ (24,3) x118,y24 ]  [ (24,4) x119,y24 ]  [ (24,5) x120,y24 ]
# [ (25,1) x121,y25 ]  [ (25,2) x122,y25 ]  [ (25,3) x123,y25 ]  [ (25,4) x124,y25 ]  [ (25,5) x125,y25 ]
# [ (26,1) x126,y26 ]  [ (26,2) x127,y26 ]  [ (26,3) x128,y26 ]  [ (26,4) x129,y26 ]  [ (26,5) x130,y26 ]
# [ (27,1) x131,y27 ]  [ (27,2) x132,y27 ]  [ (27,3) x133,y27 ]  [ (27,4) x134,y27 ]  [ (27,5) x135,y27 ]
# [ (28,1) x136,y28 ]  [ (28,2) x137,y28 ]  [ (28,3) x138,y28 ]  [ (28,4) x139,y28 ]  [ (28,5) x140,y28 ]
# [ (29,1) x141,y29 ]  [ (29,2) x142,y29 ]  [ (29,3) x143,y29 ]  [ (29,4) x144,y29 ]  [ (29,5) x145,y29 ]
# [ (30,1) x146,y30 ]  [ (30,2) x147,y30 ]  [ (30,3) x148,y30 ]  [ (30,4) x149,y30 ]  [ (30,5) x150,y30 ]
# [ (31,1) x151,y31 ]  [ (31,2) x152,y31 ]  [ (31,3) x153,y31 ]  [ (31,4) x154,y31 ]  [ (31,5) x155,y31 ]
# [ (32,1) x156,y32 ]  [ (32,2) x157,y32 ]  [ (32,3) x158,y32 ]  [ (32,4) x159,y32 ]  [ (32,5) x160,y32 ]
# [ (33,1) x161,y33 ]  [ (33,2) x162,y33 ]  [ (33,3) x163,y33 ]  [ (33,4) x164,y33 ]  [ (33,5) x165,y33 ]
# [ (34,1) x166,y34 ]  [ (34,2) x167,y34 ]  [ (34,3) x168,y34 ]  [ (34,4) x169,y34 ]  [ (34,5) x170,y34 ]
# [ (35,1) x171,y35 ]  [ (35,2) x172,y35 ]  [ (35,3) x173,y35 ]  [ (35,4) x174,y35 ]  [ (35,5) x175,y35 ]
# [ (36,1) x176,y36 ]  [ (36,2) x177,y36 ]  [ (36,3) x178,y36 ]  [ (36,4) x179,y36 ]  [ (36,5) x180,y36 ]
# [ (37,1) x181,y37 ]  [ (37,2) x182,y37 ]  [ (37,3) x183,y37 ]  [ (37,4) x184,y37 ]  [ (37,5) x185,y37 ]
# [ (38,1) x186,y38 ]  [ (38,2) x187,y38 ]  [ (38,3) x188,y38 ]  [ (38,4) x189,y38 ]  [ (38,5) x190,y38 ]
# [ (39,1) x191,y39 ]  [ (39,2) x192,y39 ]  [ (39,3) x193,y39 ]  [ (39,4) x194,y39 ]  [ (39,5) x195,y39 ]
# [ (40,1) x196,y40 ]  [ (40,2) x197,y40 ]  [ (40,3) x198,y40 ]  [ (40,4) x199,y40 ]  [ (40,5) x200,y40 ]
#
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]      [ (1,2) x2,y1 ]      [ (1,3) x3,y1 ]      [ (1,4) x4,y1 ]      [ (1,5) x5,y1 ]
# [ (2,1) x6,y2 ]      [ (2,2) x7,y2 ]      [ (2,3) x8,y2 ]      [ (2,4) x9,y2 ]      [ (2,5) x10,y2 ]
# [ (3,1) x11,y3 ]     [ (3,2) x12,y3 ]     [ (3,3) x13,y3 ]     [ (3,4) x14,y3 ]     [ (3,5) x15,y3 ]
# [ (4,1) x16,y4 ]     [ (4,2) x17,y4 ]     [ (4,3) x18,y4 ]     [ (4,4) x19,y4 ]     [ (4,5) x20,y4 ]
# [ (5,1) x21,y5 ]     [ (5,2) x22,y5 ]     [ (5,3) x23,y5 ]     [ (5,4) x24,y5 ]     [ (5,5) x25,y5 ]
# [ (6,1) x26,y6 ]     [ (6,2) x27,y6 ]     [ (6,3) x28,y6 ]     [ (6,4) x29,y6 ]     [ (6,5) x30,y6 ]
# [ (7,1) x31,y7 ]     [ (7,2) x32,y7 ]     [ (7,3) x33,y7 ]     [ (7,4) x34,y7 ]     [ (7,5) x35,y7 ]
# [ (8,1) x36,y8 ]     [ (8,2) x37,y8 ]     [ (8,3) x38,y8 ]     [ (8,4) x39,y8 ]     [ (8,5) x40,y8 ]
# [ (9,1) x41,y9 ]     [ (9,2) x42,y9 ]     [ (9,3) x43,y9 ]     [ (9,4) x44,y9 ]     [ (9,5) x45,y9 ]
# [ (10,1) x46,y10 ]   [ (10,2) x47,y10 ]   [ (10,3) x48,y10 ]   [ (10,4) x49,y10 ]   [ (10,5) x50,y10 ]
# [ (11,1) x51,y11 ]   [ (11,2) x52,y11 ]   [ (11,3) x53,y11 ]   [ (11,4) x54,y11 ]   [ (11,5) x55,y11 ]
# [ (12,1) x56,y12 ]   [ (12,2) x57,y12 ]   [ (12,3) x58,y12 ]   [ (12,4) x59,y12 ]   [ (12,5) x60,y12 ]
# [ (13,1) x61,y13 ]   [ (13,2) x62,y13 ]   [ (13,3) x63,y13 ]   [ (13,4) x64,y13 ]   [ (13,5) x65,y13 ]
# [ (14,1) x66,y14 ]   [ (14,2) x67,y14 ]   [ (14,3) x68,y14 ]   [ (14,4) x69,y14 ]   [ (14,5) x70,y14 ]
# [ (15,1) x71,y15 ]   [ (15,2) x72,y15 ]   [ (15,3) x73,y15 ]   [ (15,4) x74,y15 ]   [ (15,5) x75,y15 ]
# [ (16,1) x76,y16 ]   [ (16,2) x77,y16 ]   [ (16,3) x78,y16 ]   [ (16,4) x79,y16 ]   [ (16,5) x80,y16 ]
# [ (17,1) x81,y17 ]   [ (17,2) x82,y17 ]   [ (17,3) x83,y17 ]   [ (17,4) x84,y17 ]   [ (17,5) x85,y17 ]
# [ (18,1) x86,y18 ]   [ (18,2) x87,y18 ]   [ (18,3) x88,y18 ]   [ (18,4) x89,y18 ]   [ (18,5) x90,y18 ]
# [ (19,1) x91,y19 ]   [ (19,2) x92,y19 ]   [ (19,3) x93,y19 ]   [ (19,4) x94,y19 ]   [ (19,5) x95,y19 ]
# [ (20,1) x96,y20 ]   [ (20,2) x97,y20 ]   [ (20,3) x98,y20 ]   [ (20,4) x99,y20 ]   [ (20,5) x100,y20 ]
# [ (21,1) x101,y21 ]  [ (21,2) x102,y21 ]  [ (21,3) x103,y21 ]  [ (21,4) x104,y21 ]  [ (21,5) x105,y21 ]
# [ (22,1) x106,y22 ]  [ (22,2) x107,y22 ]  [ (22,3) x108,y22 ]  [ (22,4) x109,y22 ]  [ (22,5) x110,y22 ]
# [ (23,1) x111,y23 ]  [ (23,2) x112,y23 ]  [ (23,3) x113,y23 ]  [ (23,4) x114,y23 ]  [ (23,5) x115,y23 ]
# [ (24,1) x116,y24 ]  [ (24,2) x117,y24 ]  [ (24,3) x118,y24 ]  [ (24,4) x119,y24 ]  [ (24,5) x120,y24 ]
# [ (25,1) x121,y25 ]  [ (25,2) x122,y25 ]  [ (25,3) x123,y25 ]  [ (25,4) x124,y25 ]  [ (25,5) x125,y25 ]
# [ (26,1) x126,y26 ]  [ (26,2) x127,y26 ]  [ (26,3) x128,y26 ]  [ (26,4) x129,y26 ]  [ (26,5) x130,y26 ]
# [ (27,1) x131,y27 ]  [ (27,2) x132,y27 ]  [ (27,3) x133,y27 ]  [ (27,4) x134,y27 ]  [ (27,5) x135,y27 ]
# [ (28,1) x136,y28 ]  [ (28,2) x137,y28 ]  [ (28,3) x138,y28 ]  [ (28,4) x139,y28 ]  [ (28,5) x140,y28 ]
# [ (29,1) x141,y29 ]  [ (29,2) x142,y29 ]  [ (29,3) x143,y29 ]  [ (29,4) x144,y29 ]  [ (29,5) x145,y29 ]
# [ (30,1) x146,y30 ]  [ (30,2) x147,y30 ]  [ (30,3) x148,y30 ]  [ (30,4) x149,y30 ]  [ (30,5) x150,y30 ]
# [ (31,1) x151,y31 ]  [ (31,2) x152,y31 ]  [ (31,3) x153,y31 ]  [ (31,4) x154,y31 ]  [ (31,5) x155,y31 ]
# [ (32,1) x156,y32 ]  [ (32,2) x157,y32 ]  [ (32,3) x158,y32 ]  [ (32,4) x159,y32 ]  [ (32,5) x160,y32 ]
# [ (33,1) x161,y33 ]  [ (33,2) x162,y33 ]  [ (33,3) x163,y33 ]  [ (33,4) x164,y33 ]  [ (33,5) x165,y33 ]
# [ (34,1) x166,y34 ]  [ (34,2) x167,y34 ]  [ (34,3) x168,y34 ]  [ (34,4) x169,y34 ]  [ (34,5) x170,y34 ]
# [ (35,1) x171,y35 ]  [ (35,2) x172,y35 ]  [ (35,3) x173,y35 ]  [ (35,4) x174,y35 ]  [ (35,5) x175,y35 ]
# [ (36,1) x176,y36 ]  [ (36,2) x177,y36 ]  [ (36,3) x178,y36 ]  [ (36,4) x179,y36 ]  [ (36,5) x180,y36 ]
# [ (37,1) x181,y37 ]  [ (37,2) x182,y37 ]  [ (37,3) x183,y37 ]  [ (37,4) x184,y37 ]  [ (37,5) x185,y37 ]
# [ (38,1) x186,y38 ]  [ (38,2) x187,y38 ]  [ (38,3) x188,y38 ]  [ (38,4) x189,y38 ]  [ (38,5) x190,y38 ]
# [ (39,1) x191,y39 ]  [ (39,2) x192,y39 ]  [ (39,3) x193,y39 ]  [ (39,4) x194,y39 ]  [ (39,5) x195,y39 ]
# [ (40,1) x196,y40 ]  [ (40,2) x197,y40 ]  [ (40,3) x198,y40 ]  [ (40,4) x199,y40 ]  [ (40,5) x200,y40 ]

# %%
! gsutil cp plotly-distribution.html gs://pw-bd-project-meetup-rawdata/
# Out:
# Copying file://plotly-distribution.html [Content-Type=text/html]...
# Copying file://plotly-distribution.html [Content-Type=text/html]...
# / [1 files][  3.0 MiB/  3.0 MiB]
# Operation completed over 1 objects/3.0 MiB.
# / [1 files][  3.0 MiB/  3.0 MiB]
# Operation completed over 1 objects/3.0 MiB.

# %% [markdown]
# #### Calculate 'New Years Resolutions Effect' to establish which tags gained most interest inbetween december/january

# %%
# all available topics (if occured in one month and not other)
t = df \
    .select(explode(col("group.group_topics")).alias("topic")) \
    .select(col("topic").alias("topic")) \
    .distinct()

# select topics from january, 2019
m1 = dfWithEventTimeParts \
    .where((col("event_time_parts")[0] == '2019') & (col("event_time_parts")[1] == '1')) \
    .select(explode("group.group_topics").alias("topic")) \
    .withColumn("topic_m1", col("topic")) \
    .groupBy("topic_m1") \
    .count() \
    .alias("m1")

# select topics from december, 2018
m2 = dfWithEventTimeParts \
    .where((col("event_time_parts")[0] == '2018') & (col("event_time_parts")[1] == '12')) \
    .select(explode("group.group_topics").alias("topic")) \
    .withColumn("topic_m2", col("topic")) \
    .groupBy("topic_m2") \
    .count() \
    .alias("m2")

# calculate increase in interest per topic & select 10 highest
increase = t \
    .join(m2, t.topic == m2.topic_m2, how='full') \
    .join(m1, t.topic == m1.topic_m1, how='full') \
    .withColumn("m1", coalesce(col("m1.count"), lit("0"))) \
    .withColumn("m2", coalesce(col("m2.count"), lit("0"))) \
    .select(col("topic"), col("m1"), col("m2")) \
    .withColumn("change", col("m1")/col("m2")) \
    .withColumn("change_importance", ((col("m1")-col("m2"))/1)*(col("m1")/col("m2"))) \
    .sort(col("change_importance").desc()) \
    .repartition(1)

increase.cache()

increase.limit(20).show()

# # show topics that were absent in december, 2018 but appeared in january, 2019
# new_topics = increase \
#     .where((col("m1") > 0) & (col("m2") == 0))

increase.show()

increase.count()

! gsutil rm -fR gs://pw-bd-project-meetup-rawdata/increase-topics
increase.write.format("com.databricks.spark.csv").csv("gs://pw-bd-project-meetup-rawdata/increase-topics")
# Out:
# +--------------------+------+------+------------------+------------------+
# |               topic|    m1|    m2|            change| change_importance|
# +--------------------+------+------+------------------+------------------+
# |    Entrepreneurship|255353|127155|2.0082025873933387|257447.55529865122|
# |    Self-Improvement|317050|179649|1.7648303079894683|242489.44914806093|
# |   Social Networking|449856|302186| 1.488672539429358| 219832.2738975333|
# |Software Development|254395|137346|1.8522199408792392|216800.49185997408|
# |            RabbitMQ|   442|     1|             442.0|          194922.0|
# |Professional Netw...|219587|118552| 1.852242054119711|187141.27593798502|
# |              Social|453261|321181|1.4112322958082826|186395.56163035796|
# |         New In Town|439804|310670|1.4156629220716517|182810.21577880066|
# |           Fun Times|398135|275139|1.4470322273469047| 177979.1758347599|
# |Computer programming|194896|104110|1.8720199788685046|169953.20580155606|
# |   Business Strategy|151717| 73058| 2.076665115387774|163348.40131128693|
# |      New Technology|191888|103991|1.8452366070140684|162190.76204671556|
# |         Open Source|179953| 95133|1.8915938738397822| 160444.9923790903|
# |  Startup Businesses|159538| 79766|2.0000752200185543| 159550.0004513201|
# |     Web Development|189657|103495|1.8325233103048457| 157893.8734624861|
# |      Web Technology|150889| 78859| 1.913402401755031| 137822.3749984149|
# |            Outdoors|359369|262228|1.3704448037585613| 133126.3786819104|
# |        Spirituality|162348| 89899|  1.80589328023671|130835.16225986941|
# |          Dining Out|261996|175950|1.4890366581415175|128125.64828644502|
# |            Wellness|183120|107904|1.6970640569395017|127646.37010676156|
# +--------------------+------+------+------------------+------------------+
#
# +--------------------+------+------+------------------+------------------+
# |               topic|    m1|    m2|            change| change_importance|
# +--------------------+------+------+------------------+------------------+
# |    Entrepreneurship|255353|127155|2.0082025873933387|257447.55529865122|
# |    Self-Improvement|317050|179649|1.7648303079894683|242489.44914806093|
# |   Social Networking|449856|302186| 1.488672539429358| 219832.2738975333|
# |Software Development|254395|137346|1.8522199408792392|216800.49185997408|
# |            RabbitMQ|   442|     1|             442.0|          194922.0|
# |Professional Netw...|219587|118552| 1.852242054119711|187141.27593798502|
# |              Social|453261|321181|1.4112322958082826|186395.56163035796|
# |         New In Town|439804|310670|1.4156629220716517|182810.21577880066|
# |           Fun Times|398135|275139|1.4470322273469047| 177979.1758347599|
# |Computer programming|194896|104110|1.8720199788685046|169953.20580155606|
# |   Business Strategy|151717| 73058| 2.076665115387774|163348.40131128693|
# |      New Technology|191888|103991|1.8452366070140684|162190.76204671556|
# |         Open Source|179953| 95133|1.8915938738397822| 160444.9923790903|
# |  Startup Businesses|159538| 79766|2.0000752200185543| 159550.0004513201|
# |     Web Development|189657|103495|1.8325233103048457| 157893.8734624861|
# |      Web Technology|150889| 78859| 1.913402401755031| 137822.3749984149|
# |            Outdoors|359369|262228|1.3704448037585613| 133126.3786819104|
# |        Spirituality|162348| 89899|  1.80589328023671|130835.16225986941|
# |          Dining Out|261996|175950|1.4890366581415175|128125.64828644502|
# |            Wellness|183120|107904|1.6970640569395017|127646.37010676156|
# +--------------------+------+------+------------------+------------------+
# only showing top 20 rows
#
# +--------------------+------+------+------------------+------------------+
# |               topic|    m1|    m2|            change| change_importance|
# +--------------------+------+------+------------------+------------------+
# |    Entrepreneurship|255353|127155|2.0082025873933387|257447.55529865122|
# |    Self-Improvement|317050|179649|1.7648303079894683|242489.44914806093|
# |   Social Networking|449856|302186| 1.488672539429358| 219832.2738975333|
# |Software Development|254395|137346|1.8522199408792392|216800.49185997408|
# |            RabbitMQ|   442|     1|             442.0|          194922.0|
# |Professional Netw...|219587|118552| 1.852242054119711|187141.27593798502|
# |              Social|453261|321181|1.4112322958082826|186395.56163035796|
# |         New In Town|439804|310670|1.4156629220716517|182810.21577880066|
# |           Fun Times|398135|275139|1.4470322273469047| 177979.1758347599|
# |Computer programming|194896|104110|1.8720199788685046|169953.20580155606|
# |   Business Strategy|151717| 73058| 2.076665115387774|163348.40131128693|
# |      New Technology|191888|103991|1.8452366070140684|162190.76204671556|
# |         Open Source|179953| 95133|1.8915938738397822| 160444.9923790903|
# |  Startup Businesses|159538| 79766|2.0000752200185543| 159550.0004513201|
# |     Web Development|189657|103495|1.8325233103048457| 157893.8734624861|
# |      Web Technology|150889| 78859| 1.913402401755031| 137822.3749984149|
# |            Outdoors|359369|262228|1.3704448037585613| 133126.3786819104|
# |        Spirituality|162348| 89899|  1.80589328023671|130835.16225986941|
# |          Dining Out|261996|175950|1.4890366581415175|128125.64828644502|
# |            Wellness|183120|107904|1.6970640569395017|127646.37010676156|
# +--------------------+------+------+------------------+------------------+
#
# +--------------------+------+------+------------------+------------------+
# |               topic|    m1|    m2|            change| change_importance|
# +--------------------+------+------+------------------+------------------+
# |    Entrepreneurship|255353|127155|2.0082025873933387|257447.55529865122|
# |    Self-Improvement|317050|179649|1.7648303079894683|242489.44914806093|
# |   Social Networking|449856|302186| 1.488672539429358| 219832.2738975333|
# |Software Development|254395|137346|1.8522199408792392|216800.49185997408|
# |            RabbitMQ|   442|     1|             442.0|          194922.0|
# |Professional Netw...|219587|118552| 1.852242054119711|187141.27593798502|
# |              Social|453261|321181|1.4112322958082826|186395.56163035796|
# |         New In Town|439804|310670|1.4156629220716517|182810.21577880066|
# |           Fun Times|398135|275139|1.4470322273469047| 177979.1758347599|
# |Computer programming|194896|104110|1.8720199788685046|169953.20580155606|
# |   Business Strategy|151717| 73058| 2.076665115387774|163348.40131128693|
# |      New Technology|191888|103991|1.8452366070140684|162190.76204671556|
# |         Open Source|179953| 95133|1.8915938738397822| 160444.9923790903|
# |  Startup Businesses|159538| 79766|2.0000752200185543| 159550.0004513201|
# |     Web Development|189657|103495|1.8325233103048457| 157893.8734624861|
# |      Web Technology|150889| 78859| 1.913402401755031| 137822.3749984149|
# |            Outdoors|359369|262228|1.3704448037585613| 133126.3786819104|
# |        Spirituality|162348| 89899|  1.80589328023671|130835.16225986941|
# |          Dining Out|261996|175950|1.4890366581415175|128125.64828644502|
# |            Wellness|183120|107904|1.6970640569395017|127646.37010676156|
# +--------------------+------+------+------------------+------------------+
# only showing top 20 rows
#
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/#1548420561239512...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/_SUCCESS#1548420586939630...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00000-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420562379019...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00001-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420562413969...
# / [4 objects]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m rm ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00002-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420562380317...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00003-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420562405142...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00004-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420562419724...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/#1548420561239512...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/_SUCCESS#1548420586939630...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00000-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420562379019...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00001-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420562413969...
# / [4 objects]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m rm ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00002-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420562380317...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00003-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420562405142...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00004-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420562419724...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00005-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420562407247...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00005-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420562407247...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00006-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420562372609...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00007-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420562420530...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00006-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420562372609...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00007-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420562420530...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00008-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420563510863...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00008-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420563510863...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00009-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420563536370...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00009-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420563536370...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00010-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420563477372...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00011-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420563504098...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00010-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420563477372...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00011-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420563504098...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00012-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420563605371...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00012-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420563605371...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00013-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420563478830...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00013-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420563478830...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00014-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420563619922...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00015-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420563517152...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00014-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420563619922...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00015-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420563517152...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00016-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420564706580...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00016-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420564706580...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00017-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420564578599...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00017-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420564578599...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00018-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420564591496...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00019-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420564614318...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00018-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420564591496...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00019-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420564614318...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00020-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420564634721...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00020-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420564634721...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00021-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420564772093...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00021-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420564772093...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00022-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420564766582...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00022-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420564766582...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00023-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420564813809...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00024-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420565761076...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00023-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420564813809...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00024-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420565761076...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00025-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420565698830...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00025-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420565698830...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00026-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420565705506...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00026-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420565705506...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00027-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420565842954...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00028-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420565769424...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00027-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420565842954...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00028-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420565769424...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00029-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420565865119...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00029-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420565865119...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00030-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420566004270...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00030-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420566004270...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00031-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420565801694...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00032-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420566933073...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00033-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420566771929...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00031-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420565801694...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00032-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420566933073...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00033-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420566771929...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00034-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420566988447...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00034-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420566988447...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00035-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420566814647...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00035-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420566814647...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00036-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420566863583...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00037-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420566870116...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00036-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420566863583...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00037-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420566870116...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00038-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420566971800...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00038-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420566971800...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00039-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420567190289...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00040-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420568079417...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00039-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420567190289...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00040-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420568079417...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00041-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420567918464...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00041-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420567918464...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00042-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420568072137...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00042-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420568072137...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00043-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420567884747...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00044-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420568118737...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00043-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420567884747...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00044-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420568118737...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00045-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420568060304...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00045-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420568060304...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00046-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420568004145...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00046-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420568004145...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00047-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420568300905...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00048-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420569017618...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00047-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420568300905...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00048-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420569017618...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00049-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420569146787...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00049-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420569146787...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00050-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420569120813...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00051-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420569154375...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00052-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420569301656...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00050-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420569120813...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00051-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420569154375...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00052-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420569301656...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00053-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420569193077...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00053-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420569193077...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00054-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420569187096...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00054-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420569187096...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00055-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420569455446...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00056-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420570102827...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00055-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420569455446...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00056-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420570102827...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00057-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420570266293...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00057-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420570266293...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00058-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420570150013...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00058-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420570150013...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00059-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420570252123...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00060-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420570352686...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00059-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420570252123...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00060-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420570352686...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00061-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420570232458...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00061-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420570232458...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00062-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420570395254...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00062-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420570395254...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00063-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420570564309...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00064-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420571536832...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00063-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420570564309...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00064-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420571536832...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00065-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420571212211...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00065-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420571212211...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00066-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420571530036...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00066-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420571530036...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00067-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420571245501...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00068-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420571646434...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00067-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420571245501...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00068-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420571646434...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00069-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420571327546...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00070-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420571455244...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00069-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420571327546...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00070-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420571455244...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00071-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420571787171...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00072-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420572688138...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00071-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420571787171...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00072-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420572688138...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00073-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420572466170...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00073-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420572466170...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00074-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420572315831...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00074-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420572315831...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00075-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420572841137...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00076-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420572709857...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00075-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420572841137...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00076-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420572709857...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00077-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420572524137...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00077-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420572524137...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00078-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420572937168...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00079-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420573799291...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00078-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420572937168...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00079-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420573799291...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00080-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420572675562...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00080-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420572675562...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00081-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420573355465...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00081-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420573355465...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00082-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420573848114...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00083-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420573943367...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00082-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420573848114...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00083-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420573943367...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00084-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420573586405...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00084-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420573586405...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00085-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420574045551...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00086-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420573625733...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00085-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420574045551...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00086-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420573625733...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00087-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420574903144...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00087-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420574903144...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00088-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420574987206...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00088-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420574987206...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00089-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420573720794...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00089-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420573720794...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00090-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420574480458...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00090-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420574480458...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00091-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420574992247...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00091-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420574992247...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00092-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420574802034...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00092-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420574802034...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00093-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420575110074...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00094-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420574780076...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00095-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420574871100...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00093-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420575110074...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00094-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420574780076...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00095-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420574871100...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00096-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420575975080...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00096-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420575975080...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00097-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420576055840...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00097-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420576055840...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00098-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420575585631...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00099-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420575845301...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00098-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420575585631...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00099-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420575845301...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00100-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420576164088...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00100-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420576164088...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00101-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420576252086...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00102-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420575987216...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00101-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420576252086...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00102-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420575987216...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00103-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420575972599...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00103-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420575972599...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00104-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420577044595...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00105-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420576747661...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00104-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420577044595...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00105-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420576747661...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00106-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420577202101...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00106-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420577202101...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00107-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420576921850...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00107-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420576921850...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00108-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420577055074...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00109-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420577327264...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00110-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420577364275...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00108-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420577055074...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00109-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420577327264...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00110-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420577364275...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00111-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420577033662...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00111-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420577033662...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00112-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420578086110...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00113-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420578331240...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00112-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420578086110...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00113-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420578331240...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00114-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420577836371...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00114-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420577836371...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00115-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420577987671...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00115-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420577987671...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00116-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420578463254...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00117-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420578606345...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00116-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420578463254...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00117-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420578606345...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00118-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420578094952...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00119-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420579243987...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00118-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420578094952...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00119-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420579243987...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00120-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420578195308...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00121-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420578984113...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00120-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420578195308...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00121-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420578984113...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00122-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420579115114...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00122-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420579115114...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00123-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420579439182...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00123-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420579439182...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00124-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420579507487...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00125-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420579817859...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00124-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420579507487...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00125-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420579817859...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00126-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420579188671...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00126-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420579188671...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00127-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420580342802...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00128-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420579369076...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00127-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420580342802...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00128-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420579369076...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00129-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420580580008...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00129-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420580580008...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00130-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420580697992...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00130-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420580697992...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00131-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420581001821...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00132-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420580043033...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00131-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420581001821...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00132-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420580043033...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00133-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420580209491...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00133-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420580209491...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00134-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420581407814...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00135-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420580245394...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00134-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420581407814...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00135-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420580245394...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00136-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420581809327...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00136-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420581809327...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00137-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420580417515...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00137-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420580417515...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00138-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420581147052...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00138-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420581147052...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00139-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420581768247...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00140-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420582053590...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00139-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420581768247...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00140-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420582053590...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00141-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420581365028...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00141-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420581365028...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00142-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420581414736...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00143-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420581520453...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00142-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420581414736...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00143-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420581520453...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00144-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420582603683...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00144-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420582603683...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00145-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420582951124...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00145-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420582951124...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00146-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420582928136...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00147-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420582187568...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00146-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420582928136...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00147-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420582187568...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00148-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420583154755...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00148-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420583154755...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00149-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420583743378...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00150-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420582691598...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00149-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420583743378...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00150-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420582691598...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00151-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420584008705...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00151-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420584008705...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00152-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420582982674...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00153-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420582719249...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00152-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420582982674...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00153-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420582719249...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00154-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420584065426...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00154-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420584065426...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00155-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420583384044...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00155-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420583384044...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00156-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420583781906...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00157-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420584332397...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00156-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420583781906...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00157-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420584332397...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00158-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420583792416...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00158-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420583792416...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00159-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420584965264...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00159-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420584965264...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00160-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420584053505...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00160-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420584053505...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00161-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420585186700...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00162-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420585147743...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00161-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420585186700...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00162-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420585147743...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00163-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420584472888...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00163-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420584472888...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00164-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420585567339...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00164-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420585567339...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00165-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420586072113...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00165-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420586072113...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00166-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420586262824...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00166-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420586262824...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00167-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420584924109...
# Removing gs://pw-bd-project-meetup-rawdata/increase-topics/part-00167-50d57b9a-c883-4337-9779-495933bf92e5-c000.csv#1548420584924109...
# / [170 objects]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m rm ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 170 objects.
# / [170 objects]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m rm ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
#
# Operation completed over 170 objects.
